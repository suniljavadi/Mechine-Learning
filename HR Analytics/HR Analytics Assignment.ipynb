# %%
#import required libraries
import numpy as np #numerical analysation
import pandas as pd #dataset
import matplotlib.pyplot as plt #visualization
import seaborn as sns #better visualization
import warnings
warnings.simplefilter("ignore")

# %%
#load the dataset
data=pd.read_csv("people.csv")

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#EDA-------explore the dataset
data.head() #returns the top 5 records from the dataset
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
data.tail() #returns the lower 5 records
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
data.shape # shape of the dataset(rows and columns present in the dataset(14999 rows,10 columns))
# Out:
# (14999, 10)

# %%
data.info() #returns the entire information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.describe() # returns the description of the data in the dataset
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
#data preprocessing
#try to find out the impurities and remove them
#find out the null values

data.isnull()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isna()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isna().sum() #returns the count of null valyes from every columns
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#dropna()---drops or removes all the missing values.
#mean,median--------replace the null records with mean/median in case of numerical data
#mod-----for categorical data

# %%
#checking the duplicate records
data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# removing the duplicate records

data=data.drop_duplicates(keep="first")

#keep="first"---removes duplicates and keep the first record
#keep="last"---removes duplicates and keep the last record

# %%
data.shape
# Out:
# (11991, 10)

# %%
14999-3008
# Out:
# 11991

# %%
#correlation

data.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
sns.heatmap(data.corr(),cmap="Blues")
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(),cmap="Blues",annot=True)
# Out:
# <Axes: >

# %%
#data visualization, analyzing different features

ftr=["dept","salary","numberOfProjects","timeSpent.company","workAccident","promotionInLast5years"]

# %%
ftr
# Out:
# ['dept',
#  'salary',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years']

# %%
fig=plt.subplots(figsize=(20,25)) #to plot multiple plots

for p,q in enumerate(ftr):
    plt.subplot(3,2,p+1)
    plt.subplots_adjust(hspace=0.5)
    sns.countplot(x=q,data=data,hue="left")
    plt.xticks(rotation=90)

# %%
#conclusion:

#promotion---likely to quit----have not received

#time with company-----after 3-6 years crucial point for the employees

#number of projects--------if the oppurtunities are less oe if the employee is over burdened,
# there is more chance of the employees to quit

#salary---no much salary provided
